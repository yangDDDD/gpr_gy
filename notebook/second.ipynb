# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
import gc
print(os.listdir("../input"))
# Out:
# ['gap-validation.tsv', 'test_stage_1.tsv', 'sample_submission_stage_1.csv', 'gap-test.tsv', 'gap-development.tsv']

# %%
DATA_ROOT = '../input/'
GAP_DATA_FOLDER = os.path.join(DATA_ROOT, 'gap-coreference')
SUB_DATA_FOLDER = os.path.join(DATA_ROOT, 'gendered-pronoun-resolution')
# FAST_TEXT_DATA_FOLDER = os.path.join(DATA_ROOT, 'fasttext-crawl-300d-2m')

# %%
test_df_path = os.path.join(DATA_ROOT, 'gap-development.tsv')
train_df_path = os.path.join(DATA_ROOT, 'gap-test.tsv')
dev_df_path = os.path.join(DATA_ROOT, 'gap-validation.tsv')

train_df = pd.read_csv(train_df_path, sep='\t')
test_df = pd.read_csv(test_df_path, sep='\t')
dev_df = pd.read_csv(dev_df_path, sep='\t')

# pd.options.display.max_colwidth = 1000

# %%
test_df.head()
# Out:
#               ID                                               Text Pronoun  \
# 0  development-1  Zoe Telford -- played the police officer girlf...     her
# 1  development-2  He grew up in Evanston, Illinois the second ol...     His
# 2  development-3  He had been reelected to Congress, but resigne...     his
# 3  development-4  The current members of Crime have also perform...     his
# 4  development-5  Her Santa Fe Opera debut in 2005 was as Nuria ...     She
#
#    Pronoun-offset                  A  A-offset  A-coref                B  \
# 0             274     Cheryl Cassidy       191     True          Pauline
# 1             284          MacKenzie       228     True    Bernard Leach
# 2             265            Angeloz       173    False       De la Sota
# 3             321               Hell       174    False  Henry Rosenthal
# 4             437  Kitty Oppenheimer       219    False           Rivera
#
#    B-offset  B-coref                                                URL
# 0       207    False  http://en.wikipedia.org/wiki/List_of_Teachers_...
# 1       251    False      http://en.wikipedia.org/wiki/Warren_MacKenzie
# 2       246     True  http://en.wikipedia.org/wiki/Jos%C3%A9_Manuel_...
# 3       336     True          http://en.wikipedia.org/wiki/Crime_(band)
# 4       294     True        http://en.wikipedia.org/wiki/Jessica_Rivera

# %%
spacy_model = "en_core_web_sm"

# %%
from spacy.lang.en import English
from spacy.pipeline import DependencyParser
import spacy
from nltk import Tree

from keras.preprocessing import sequence
from keras.preprocessing import text as ktext
# Out:
# Using TensorFlow backend.

# %%
nlp = spacy.load(spacy_model)

def bs(list_, target_):
    lo, hi = 0, len(list_) -1
    
    while lo < hi:
        mid = lo + int((hi - lo) / 2)
        
        if target_ < list_[mid]:
            hi = mid
        elif target_ > list_[mid]:
            lo = mid + 1
        else:
            return mid + 1
    return lo

def bs_(list_, target_):
    lo, hi = 0, len(list_) -1
    
    while lo < hi:
        mid = lo + int((hi - lo) / 2)
        
        if target_ < list_[mid]:
            hi = mid
        elif target_ > list_[mid]:
            lo = mid + 1
        else:
            return mid
    return lo

def ohe_dist(dist, buckets):
    idx = bs_(buckets, dist)
    oh = np.zeros(shape=(len(buckets),), dtype=np.float32)
    oh[idx] = 1
    
    return oh

# %%
num_pos_features = 45

# %%
def extrac_positional_features(text, char_offset1, char_offset2):
    doc = nlp(text)
    max_len = 64
    
    # char offset to token offset
    lens = [token.idx for token in doc]
    mention_offset1 = bs(lens, char_offset1) - 1
    mention_offset2 = bs(lens, char_offset2) - 1
    
    # token offset to sentence offset
    lens = [len(sent) for sent in doc.sents]
    acc_lens = [len_ for len_ in lens]
    pre_len = 0
    for i in range(0, len(acc_lens)):
        pre_len += acc_lens[i]
        acc_lens[i] = pre_len
    sent_index1 = bs(acc_lens, mention_offset1)
    sent_index2 = bs(acc_lens, mention_offset2)
    
    sent1 = list(doc.sents)[sent_index1]
    sent2 = list(doc.sents)[sent_index2]
    
    # buckets
    bucket_dist = [1, 2, 3, 4, 5, 8, 16, 32, 64]
    
    # relative distance
    dist = mention_offset2 - mention_offset1
    dist_oh = ohe_dist(dist, bucket_dist)
    
    # buckets
    bucket_pos = [0, 1, 2, 3, 4, 5, 8, 16, 32]
    
    # absolute position in the sentence
    sent_pos1 = mention_offset1 + 1
    if sent_index1 > 0:
        sent_pos1 = mention_offset1 - acc_lens[sent_index1-1]
    sent_pos_oh1 = ohe_dist(sent_pos1, bucket_pos)
    sent_pos_inv1 = len(sent1) - sent_pos1
    assert sent_pos_inv1 >= 0
    sent_pos_inv_oh1 = ohe_dist(sent_pos_inv1, bucket_pos)
    
    sent_pos2 = mention_offset2 + 1
    if sent_index2 > 0:
        sent_pos2 = mention_offset2 - acc_lens[sent_index2-1]
    sent_pos_oh2 = ohe_dist(sent_pos2, bucket_pos)
    sent_pos_inv2 = len(sent2) - sent_pos2
    if sent_pos_inv2 < 0:
        print(sent_pos_inv2)
        print(len(sent2))
        print(sent_pos2)
        raise ValueError
    sent_pos_inv_oh2 = ohe_dist(sent_pos_inv2, bucket_pos)
    
    sent_pos_ratio1 = sent_pos1 / len(sent1)
    sent_pos_ratio2 = sent_pos2 / len(sent2)
    
    return dist_oh, sent_pos_oh1, sent_pos_oh2, sent_pos_inv_oh1, sent_pos_inv_oh2

# %%
def create_dist_features(df, text_column, pronoun_offset_column, name_offset_column):
    text_offset_list = df[[text_column, pronoun_offset_column, name_offset_column]].values.tolist()
    num_features = num_pos_features
    
    pos_feature_matrix = np.zeros(shape=(len(text_offset_list), num_features))
    for text_offset_index in range(len(text_offset_list)):
        text_offset = text_offset_list[text_offset_index]
        dist_oh, sent_pos_oh1, sent_pos_oh2, sent_pos_inv_oh1, sent_pos_inv_oh2 = extrac_positional_features(text_offset[0], text_offset[1], text_offset[2])
        
        feature_index = 0
        pos_feature_matrix[text_offset_index, feature_index:feature_index+len(dist_oh)] = np.asarray(dist_oh)
        feature_index += len(dist_oh)
        pos_feature_matrix[text_offset_index, feature_index:feature_index+len(sent_pos_oh1)] = np.asarray(sent_pos_oh1)
        feature_index += len(sent_pos_oh1)
        pos_feature_matrix[text_offset_index, feature_index:feature_index+len(sent_pos_oh2)] = np.asarray(sent_pos_oh2)
        feature_index += len(sent_pos_oh2)
        pos_feature_matrix[text_offset_index, feature_index:feature_index+len(sent_pos_inv_oh1)] = np.asarray(sent_pos_inv_oh1)
        feature_index += len(sent_pos_inv_oh1)
        pos_feature_matrix[text_offset_index, feature_index:feature_index+len(sent_pos_inv_oh2)] = np.asarray(sent_pos_inv_oh2)
        feature_index += len(sent_pos_inv_oh2)
    
    return pos_feature_matrix

# %%
max_len = 50 # longer than 99% of the sentences

# %%
seq_list = list()
def extract_sents(text, char_offset_p, char_offset_a, char_offset_b, id):
    global max_len
    global seq_list
    
    seq_list.append(list())
    
    doc = nlp(text)
    token_lens = [token.idx for token in doc]
    
    char_offsets = [char_offset_p, char_offset_a, char_offset_b]
    sent_list = list()
    
    for char_offset in char_offsets:
        # char offset to token offset
        mention_offset = bs(token_lens, char_offset) - 1
        # mention_word
        mention = doc[mention_offset]
    
        # token offset to sentence offset
        lens = [len(sent) for sent in doc.sents]
        acc_lens = [len_ for len_ in lens]
        pre_len = 0
        for i in range(0, len(acc_lens)):
            pre_len += acc_lens[i]
            acc_lens[i] = pre_len
        sent_index = bs(acc_lens, mention_offset)
        # mention sentence
        sent = list(doc.sents)[sent_index]
        
        # absolute position in the sentence
        sent_pos = mention_offset + 1
        if sent_index > 0:
            sent_pos = mention_offset - acc_lens[sent_index-1]
        
        # clip the sentence if it is longer than max length
        if len(sent) > max_len:
            # make sure the mention is in the sentence span
            if sent_pos < max_len-1:
                sent_list.append(sent[0:max_len].text)
                sent_list.append(sent_pos)
                seq_list[-1].append(sent[0:max_len])
            else:
                sent_list.append(sent[sent_pos-max_len+2 : min(sent_pos+2, len(sent))].text)
                sent_list.append(max_len-2)
                seq_list[-1].append(sent[sent_pos-max_len+2 : min(sent_pos+2, len(sent))])
        else:
            sent_list.append(sent.text)
            sent_list.append(sent_pos)
            seq_list[-1].append(sent)
        
    return pd.Series([id] + sent_list, index=['ID', 'Pronoun-Sent', 'Pronoun-Sent-Offset', 'A-Sent', 'A-Sent-Offset', 'B-Sent', 'B-Sent-Offset'])

def add_sent_columns(df, text_column, pronoun_offset_column, a_offset_column, b_offset_column):
    global seq_list
    seq_list = list()
    sent_df = df.apply(lambda row: extract_sents(row.loc[text_column], row[pronoun_offset_column], row[a_offset_column], row[b_offset_column], row['ID']), axis=1)
    df = df.join(sent_df.set_index('ID'), on='ID')
    return df, seq_list

# %%
seq_list = list()
train_df, train_tokenized = add_sent_columns(train_df, 'Text', 'Pronoun-offset', 'A-offset', 'B-offset')
seq_list = list()
test_df, test_tokenized = add_sent_columns(test_df, 'Text', 'Pronoun-offset', 'A-offset', 'B-offset')
seq_list = list()
dev_df, dev_tokenized = add_sent_columns(dev_df, 'Text', 'Pronoun-offset', 'A-offset', 'B-offset')

# df apply will call the first row twice, remove the first one
train_tokenized = train_tokenized[1:]
test_tokenized = test_tokenized[1:]
dev_tokenized = dev_tokenized[1:]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7222de5fcf3f> in <module>()
#       4 test_df, test_tokenized = add_sent_columns(test_df, 'Text', 'Pronoun-offset', 'A-offset', 'B-offset')
#       5 seq_list = list()
# ----> 6 dev_df, dev_tokenized = add_sent_columns(dev_df, 'Text', 'Pronoun-offset', 'A-offset', 'B-offset')
#       7
#       8 # df apply will call the first row twice, remove the first one
#
# <ipython-input-15-64efc7de81c9> in add_sent_columns(df, text_column, pronoun_offset_column, a_offset_column, b_offset_column)
#      55     global seq_list
#      56     seq_list = list()
# ---> 57     sent_df = df.apply(lambda row: extract_sents(row.loc[text_column], row[pronoun_offset_column], row[a_offset_column], row[b_offset_column], row['ID']), axis=1)
#      58     df = df.join(sent_df.set_index('ID'), on='ID')
#      59     return df, seq_list
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-15-64efc7de81c9> in <lambda>(row)
#      55     global seq_list
#      56     seq_list = list()
# ---> 57     sent_df = df.apply(lambda row: extract_sents(row.loc[text_column], row[pronoun_offset_column], row[a_offset_column], row[b_offset_column], row['ID']), axis=1)
#      58     df = df.join(sent_df.set_index('ID'), on='ID')
#      59     return df, seq_list
#
# <ipython-input-15-64efc7de81c9> in extract_sents(text, char_offset_p, char_offset_a, char_offset_b, id)
#       6     seq_list.append(list())
#       7
# ----> 8     doc = nlp(text)
#       9     token_lens = [token.idx for token in doc]
#      10
#
# /usr/local/lib/python3.5/dist-packages/spacy/language.py in __call__(self, text, disable)
#     344             if not hasattr(proc, '__call__'):
#     345                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 346             doc = proc(doc)
#     347             if doc is None:
#     348                 raise ValueError(Errors.E005.format(name=name))
#
# pipeline.pyx in spacy.pipeline.Tagger.__call__()
#
# pipeline.pyx in spacy.pipeline.Tagger.predict()
#
# /usr/local/lib/python3.5/dist-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.5/dist-packages/thinc/api.py in predict(self, X)
#      53     def predict(self, X):
#      54         for layer in self._layers:
# ---> 55             X = layer(X)
#      56         return X
#      57
#
# /usr/local/lib/python3.5/dist-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.5/dist-packages/thinc/api.py in predict(seqs_in)
#     291     def predict(seqs_in):
#     292         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 293         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     294         return layer.ops.unflatten(X, lengths, pad=pad)
#     295
#
# /usr/local/lib/python3.5/dist-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.5/dist-packages/thinc/api.py in predict(self, X)
#      53     def predict(self, X):
#      54         for layer in self._layers:
# ---> 55             X = layer(X)
#      56         return X
#      57
#
# /usr/local/lib/python3.5/dist-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     159             Must match expected shape
#     160         '''
# --> 161         return self.predict(x)
#     162
#     163     def pipe(self, stream, batch_size=128):
#
# /usr/local/lib/python3.5/dist-packages/thinc/neural/_classes/model.py in predict(self, X)
#     123
#     124     def predict(self, X):
# --> 125         y, _ = self.begin_update(X)
#     126         return y
#     127
#
# /usr/local/lib/python3.5/dist-packages/thinc/api.py in uniqued_fwd(X, drop)
#     372                                                     return_counts=True)
#     373         X_uniq = layer.ops.xp.ascontiguousarray(X[ind])
# --> 374         Y_uniq, bp_Y_uniq = layer.begin_update(X_uniq, drop=drop)
#     375         Y = Y_uniq[inv].reshape((X.shape[0],) + Y_uniq.shape[1:])
#     376         def uniqued_bwd(dY, sgd=None):
#
# /usr/local/lib/python3.5/dist-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# /usr/local/lib/python3.5/dist-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      49
#      50     def begin_update(self, X, drop=0.):
# ---> 51         X, backprop_child = self.child.begin_update(X, drop=0.)
#      52         N, mu, var = _get_moments(self.ops, X)
#      53
#
# /usr/local/lib/python3.5/dist-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      67         W = self.W.reshape((self.nO * self.nP, self.nI))
#      68         drop *= self.drop_factor
# ---> 69         output__boc = self.ops.batch_dot(X__bi, W)
#      70         output__boc += self.b.reshape((self.nO*self.nP,))
#      71         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
train_df
# Out:
#              ID                                               Text Pronoun  \
# 0        test-1  Upon their acceptance into the Kontinental Hoc...     His
# 1        test-2  Between the years 1979-1981, River won four lo...     him
# 2        test-3  Though his emigration from the country has aff...      He
# 3        test-4  At the trial, Pisciotta said: ``Those who have...     his
# 4        test-5  It is about a pair of United States Navy shore...     his
# 5        test-6  The others were Adam Baldwin (Jayne Cobb in Fi...     her
# 6        test-7  Allison Fischer (born October 19, 1988) is an ...     She
# 7        test-8  The monster arrives and bites Jeni's tongue, b...     her
# 8        test-9  On June 4, 1973 at the Felt Forum, Madison Squ...      he
# 9       test-10  Go Away (Lorrie Morgan song) ``Go Away'' is a ...     her
# 10      test-11  Taken in by S.H.I.E.L.D. she is under the dire...     her
# 11      test-12  Neither knows the truth about their respective...     she
# 12      test-13  He was a lawyer in Pulaski County before servi...     His
# 13      test-14  He left the Army in 1946. As the recipient of ...      he
# 14      test-15  Nicola Alexis is a British actress best known ...     She
# 15      test-16  Indeed, Buster was fully intended to exist in ...     his
# 16      test-17  In the late 1970s, she toured in musical comed...     She
# 17      test-18  Jennifer Slept Here ended in 1984, enabling he...     her
# 18      test-19  On May 17, 2004, when the very successful Die ...     her
# 19      test-20  Antonio di Filippo di Lorenzo Niccolini (Flore...      He
# 20      test-21  Rabelais traveled frequently to Rome with his ...     his
# 21      test-22  The team spends some time in a beach-house on ...     her
# 22      test-23  After seeing an image of Venus, Vulcan, and Cu...      he
# 23      test-24  Jones played piano for a concert with the Lond...      He
# 24      test-25  That opened the door for Racing Engineering's ...     his
# 25      test-26  It explored their interconnection and geograph...     his
# 26      test-27  Kathleen first appears when Theresa visits her...     her
# 27      test-28  The central characters are Juliana Crain, Fran...     her
# 28      test-29  The second season was released on December 16,...     she
# 29      test-30  A 1969 film, directed and co-written by Arthur...     his
# ...         ...                                                ...     ...
# 1970  test-1971  Probably the most 'in charge' of any female ar...     She
# 1971  test-1972  He gave all of his power to Arwa, and she had ...     she
# 1972  test-1973  She defeated Kaia Kanepi 6--4, 6--4, Aravane R...     She
# 1973  test-1974  The novel of When Knighthood Was in Flower, by...     her
# 1974  test-1975  In the seventh season, however, she finally st...     her
# 1975  test-1976  He finds connections to both Lady Dedlock and ...     her
# 1976  test-1977  She also played minor role in Love Keeps Going...     She
# 1977  test-1978  Tina is the mother of Kayla, who is the assist...     she
# 1978  test-1979  Sanchez has also competed in and won Miss Rive...     her
# 1979  test-1980  After Richard III was defeated by Henry Tudor ...     she
# 1980  test-1981  She was linked to other authors of the time, s...     her
# 1981  test-1982  Still sure there was some sort of error in her...     her
# 1982  test-1983  Prince Edward is an important character in Nor...     her
#       A-coref                   B  B-offset  B-coref  \
# 0       False              Dehner       366     True
# 1        True  Alfredo Di St*fano       390    False
# 2        True              Saddam       295    False
# 3       False           Pisciotta       536     True
# 4        True         Rock Reilly       559    False
# 5        True              Keller       310    False
# 6        True        Grace Smythe       290    False
# 7       False                Jeni       277     True
# 8        True         Greg Joiner       169    False
# 9       False       Lorrie Morgan       154     True
# 10      False             Johnson       369     True
# 11      False           Rosalinda       207    False
# 12      False             Hubbell       232     True
# 13      False              Hanson       222     True
# 14       True     WPC Ruby Buxton        70    False
# 15       True              Buster       445    False
# 16       True          Ann Miller       282    False
# 17      False             Jillian       228     True
# 18       True       Marge Simpson       241    False
# 19       True             Filippo       248    False
# 20      False            Rabelais       314     True
# 21       True               Sarah       272    False
# 22       True              Aeneas       231    False
# 23       True        Chris Kimsey       495    False
# 24       True        Luca Filippi       361    False
# 25      False        Huang Zongxi       325     True
# 26       True             Theresa        28    False
# 27      False             Juliana       312     True
# 28      False             Juliana       231    False
# 29       True       Woody Guthrie       301    False
# ...       ...                 ...       ...      ...
# 1970    False          Ann Powers       367    False
# 1971    False                Arwa       308     True
# 1972     True      Vera Zvonareva       301    False
# 1973    False                Mary       440     True
# 1974     True               Kelly       279    False
# 1975    False              Esther       375     True
# 1976     True             Gu Long       266    False
# 1977     True              Camryn       238    False
# 1978     True     Chelsea Caswell       233    False
# 1979     True  Susan Higginbotham       297    False
# 1980    False              Morvan       334     True
# 1981    False           Christine       269     True
# 1982    False    Caroline Matilda       141     True
# 1983    False                Cook       300     True
# 1984    False              Carola       318     True
# 1985    False   Thomasine Clopton       357     True
# 1986     True        Anne Egerton       250    False
# 1987     True               Naomi       219    False
# 1988    False               Sadie       425     True
# 1989     True        Mabel Martha       371    False
# 1990    False             Civille       326     True
# 1991    False             Johnson       311     True
# 1992     True               Elsie       446    False
# 1993    False         Miss Foozie       281     True
# 1994     True      Venus Williams       324    False
# 1995     True        Peggy Michel       432    False
# 1996     True      Barbara Morgan       404    False
# 1997     True  Natasha Henstridge       412    False
# 1998     True              Bergen       274    False
# 1999     True       Polly O'Keefe       260    False
#
#                                                     URL  \
# 0            http://en.wikipedia.org/wiki/Jeremy_Dehner
# 1          http://en.wikipedia.org/wiki/Norberto_Alonso
# 2                 http://en.wikipedia.org/wiki/Aladhadh
# 3        http://en.wikipedia.org/wiki/Gaspare_Pisciotta
# 4                  http://en.wikipedia.org/wiki/Chasers
# 5          http://en.wikipedia.org/wiki/Jennifer_Keller
# 6          http://en.wikipedia.org/wiki/Allison_Fischer
# 7      http://en.wikipedia.org/wiki/Leprechaun:_Origins
# 8             http://en.wikipedia.org/wiki/Edwin_Malave
# 9     http://en.wikipedia.org/wiki/Go_Away_(Lorrie_M...
# 10           http://en.wikipedia.org/wiki/Daisy_Johnson
# 11    http://en.wikipedia.org/wiki/Rosalinda_(Philip...
# 12         http://en.wikipedia.org/wiki/Webster_Hubbell
# 13    http://en.wikipedia.org/wiki/Raymond_Hanson_(c...
# 14           http://en.wikipedia.org/wiki/Nicola_Alexis
# 15          http://en.wikipedia.org/wiki/Spike_Witwicky
# 3     However the MPs Mattarella, Alliata and Marche...              5
# 4     A day before his discharge, Eddie is assigned ...              6
# 5     The producers decided to cast Jewel Staite for...              5
# 6     Also in 2000, Allison performed on Broadway at...              4
# 7     The remaining trio head back to the cottage to...             21
# 8     Malave took a fight in Boston, Mass. against G...              0
# 9     Go Away (Lorrie Morgan song) ``Go Away'' is a ...             20
# 10    She possesses a ``Level 10'' security clearanc...             22
# 11    Dolores and Rosalinda's sister, Fedra (Halili)...              0
# 12    When Clinton became President, Hubbell was app...              1
# 13    Following a year of study with Alex Bernard, t...              6
# 14    Nicola Alexis is a British actress best known ...              1
# 15    Returning home from college to discover that h...             15
# 16    After appearing with Mickey Rooney in the play...             16
# 17    Dunaway and Vereen were nominated for Golden G...              0
# 18    Engelke is the German voice of Marge Simpson o...              0
# 19    Antonio di Filippo di Lorenzo Niccolini (Flore...              1
# 20    Only the protection of du Bellay saved Rabelai...              4
# 21    For some time, Caitlin Fairchild had no idea S...              4
# 22    Chaucer goes into much further detail during t...              0
# 23    In the late 1980s Jones began working with Dur...              4
# 24    Oliver Turvey finished fifth for iSport ahead ...              0
# 25    The work was later lauded by Liang Qichao as a...              6
# 26    Kathleen first appears when Theresa visits her...              1
# 27    Juliana Crain is a San Francisco woman who bec...             18
# 28    Karen and Lem confront Juliana for not shootin...              0
# 29    This film, also called Alice's Restaurant, fea...             10
# ...                                                 ...            ...
# 1970  Noting influences by Tina Turner and Barbra St...              6
# 1971  In contrast to her mother-in-law, queen Asma, ...             11
# 1972  At the2011 Australian Open, Jovanovski defeate...              5
# 1973  The drama series The Tudors : portrays the rel...             20
# 1974  Following Jason Priestley's departure from the...              9
# 1975  Realizing that Esther is her daughter whom she...             21
# 1976  In 2012, Liu acted with Tang Guoqiang and Zhan...              3
# 1977  Kayla hopes that Camryn can uphold the respons...              0
# 1978  As Miss South Las Vegas USA, Sanchez was crown...              7
# 1979  Catherine is the main protagonist in Susan Hig...              0
# 1980  Together with Blanca Santa Cruz Ossa and her s...              9
# 1981  With that, Donna realizes that Christine has c...              3
# 1982  Prince Edward is an important character in Nor...              8
# 1983  She has two children, Charlie Williams, son to...             21
# 1984  Silvia also claimed the only reason Carola qua...              0
# 1985  His wife Mary died in 1615, and he followed th...              2
# 1986  His legal connections introduced him to the Ty...             18
# 1987  While Orpah returns and leaves Judaism, Ruth c...              7
# 1988  After she confronts Dolly and finds out that T...              3
# 1989  He twice married, the first to Elizabeth Mann ...              7
# 1990  During this time she discerned, under the ment...             10
# 1991  Johnson started formal dance training at the a...             29
# 1992  In 1966, Holly Stevens, Wallace and Elsie's da...              3
# 1993  On August 24, 2007, Photographer Mia Algotti f...              7
# 1994  Goolagong Cawley is 12th on the list of all-ti...              0
# 1995  Also in 1974, Goolagong Cawley teamed up with ...              4
# 1996  The last victim was Esther Sheryl Wood, 27, wh...              4
# 1997  She also made a guest appearance as Kayla on t...              7
# 1998  After delivery, Irma served on the Bergen-- Ne...              3
# 1999  Vicky Austin is about two years older than Pol...              0
#
#                                                  B-Sent  B-Sent-Offset
# 0     Former NHLer Gary Suter and Olympic-medalist B...             11
# 1     During the 1981 ``Nacional'' tournament (which...             21
# 2     A contributor to Iraq's liberation, Ali Aladha...             15
# 3     During his trial Pisciotta could not account f...              3
# 4     A day before his discharge, Eddie is assigned ...             31
# 5     The producers decided to cast Jewel Staite for...             11
# 6     Also in 2000, Allison performed on Broadway at...             13
# 7     The remaining trio head back to the cottage to...             26
# 8     Malave took a fight in Boston, Mass. against G...              9
# 9     Go Away (Lorrie Morgan song) ``Go Away'' is a ...             33
# 10    In her most visible action, Johnson has helped...              6
# 11    Dolores and Rosalinda's sister, Fedra (Halili)...              2
# 12    When Clinton became President, Hubbell was app...              5
# 13    Following a year of study with Alex Bernard, t...             12
# 14    Nicola Alexis is a British actress best known ...             14
# 15    Returning home from college to discover that h...             29
# 16    After appearing with Mickey Rooney in the play...             33
# 17    Dunaway and Vereen were nominated for Golden G...             11
# 18    Engelke is the German voice of Marge Simpson o...              6
# 19    He was born into a noble Florentine family, th...             13
# 20    Only the protection of du Bellay saved Rabelai...              7
# 21    For some time, Caitlin Fairchild had no idea S...              9
# 22    Chaucer goes into much further detail during t...             10
# 23    ``This Is How A Road Gets Made'', before being...             20
# 24    Oliver Turvey finished fifth for iSport ahead ...             11
# 25    At the time of his death, Huang Zongxi left be...              7
# 26    Kathleen first appears when Theresa visits her...              5
# 27    Juliana Crain is a San Francisco woman who bec...             28
# 28    Karen and Lem confront Juliana for not shootin...              4
# 29    The part of his father Woody Guthrie, who had ...              5
# ...                                                 ...            ...
# 1970  Noting influences by Tina Turner and Barbra St...             12
# 1971  In contrast to her mother-in-law, queen Asma, ...             13
# 1972  At the2011 Australian Open, Jovanovski defeate...             28
# 1973  The drama series The Tudors : portrays the rel...             28
# 1974  Following Jason Priestley's departure from the...             21
# 1975  Realizing that Esther is her daughter whom she...             25
# 1976           Gu Long's wuxia novel of the same title.              0
# 1977  Kayla hopes that Camryn can uphold the respons...              3
# 1978  As Miss South Las Vegas USA, Sanchez was crown...             15
# 1979  Catherine is the main protagonist in Susan Hig...              6
# 1980  Together with Blanca Santa Cruz Ossa and her s...             11
# 1981  With that, Donna realizes that Christine has c...              6
# 1982  Prince Edward is an important character in Nor...             28
# 1983  She has two children, Charlie Williams, son to...             37
# 1984  Silvia also claimed the only reason Carola qua...              6
# 1985  His wife Mary died in 1615, and he followed th...             17
# 1986  His legal connections introduced him to the Ty...             37
# 1987  While Orpah returns and leaves Judaism, Ruth c...             12
# 1988  After she confronts Dolly and finds out that T...             15
# 1989  Before she died on June 21, 1895, however, the...             17
# 1990  In the early 1970s, while raising her children...             10
# 1991  Johnson started formal dance training at the a...             37
# 1992  In 1966, Holly Stevens, Wallace and Elsie's da...              8
# 1993  On August 24, 2007, Photographer Mia Algotti f...             11
# 1994  Goolagong Cawley is 12th on the list of all-ti...             17
# 1995  Also in 1974, Goolagong Cawley teamed up with ...              9
# 1996  He first shot her in the back and leg and then...             17
# 1997    She Spies alongside Natasha Henstridge in 2003.              3
# 1998  After delivery, Irma served on the Bergen-- Ne...              7
# 1999  Vicky Austin is about two years older than Pol...              8
#
# [2000 rows x 17 columns]
